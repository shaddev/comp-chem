# %%
import numpy as np
from openbabel import openbabel as ob
from openbabel import pybel

# %%
molecules = pybel.readfile("sdf", "benzene.sdf")
for mol in molecules:

    n = len(mol.atoms)

    # Pre-allocate memory for  the adjacency matrix
    A = np.zeros((n, n), dtype=int)

    # Loop over molecular bonds
    for bond in ob.OBMolBondIter(mol.OBMol):
        # Bonds are 1-indexed
        i: int = bond.GetBeginAtomIdx() - 1
        j: int = bond.GetEndAtomIdx() - 1

        # A molecular graph is undirected
        A[i, j] = A[j, i] = bond.GetBondOrder()
    print(A)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25860\1236451717.py in <module>
# ----> 1 molecules = pybel.readfile("sdf", "benzene.sdf")
#       2 for mol in molecules:
#       3
#       4     n = len(mol.atoms)
#       5
#
# c:\Users\shada\AppData\Local\Programs\Python\Python38\lib\site-packages\openbabel\pybel.py in readfile(format, filename, opt)
#     157             obconversion.AddOption(k, obconversion.INOPTIONS, str(v))
#     158     if not formatok:
# --> 159         raise ValueError("%s is not a recognised Open Babel format" % format)
#     160     if not os.path.isfile(filename):
#     161         raise IOError("No such file: '%s'" % filename)
#
# ValueError: sdf is not a recognised Open Babel format
